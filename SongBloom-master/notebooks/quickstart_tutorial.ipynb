# %% [markdown]
# # SongBloom Next-Gen X2 - Quick Start Tutorial
#
# This notebook demonstrates how to use SongBloom Next-Gen X2 for AI music generation.
#
# ## Features Covered:
# - Loading the model with optimizations
# - Generating music from lyrics and prompts
# - Using different configurations
# - Comparing quality vs performance

# %% [markdown]
# ## 1. Setup and Installation

# %%
# Install dependencies (run once)
# !pip install -r ../requirements.txt

# %%
# Imports
import sys
sys.path.append('..')

import torch
import torchaudio
from IPython.display import Audio, display
import matplotlib.pyplot as plt
import numpy as np

from infer_optimized import load_config, hf_download, optimize_model, apply_quantization
from SongBloom.models.songbloom.songbloom_pl import SongBloom_Sampler

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name()}")

# %% [markdown]
# ## 2. Generate Music
#
# See [NEXTGEN_X2_GUIDE.md](../NEXTGEN_X2_GUIDE.md) for complete documentation.
